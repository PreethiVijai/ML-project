# %%
import pandas as pd
import data

data.food["ACCESS"]
# Out:
#       State      County  LACCESS_POP10  LACCESS_POP15  PCH_LACCESS_POP_10_15  \
# FIPS
# 1001     AL     Autauga   18428.439685   17496.693038              -5.056026
# 1003     AL     Baldwin   35210.814078   30561.264430             -13.204891
# 1005     AL     Barbour    5722.305602    6069.523628               6.067799
# 1007     AL        Bibb    1044.867327     969.378841              -7.224696
# 1009     AL      Blount    1548.175559    3724.428242             140.568857
# ...     ...         ...            ...            ...                    ...
# 56037    WY  Sweetwater   13391.715505   18934.737809              41.391428
# 56039    WY       Teton    6212.423697    6212.390430              -0.000535
# 56041    WY       Uinta    4270.147119    4686.017653               9.739021
# 56043    WY    Washakie     931.411647     931.411647               0.000000
# 56045    WY      Weston    1240.493102    1237.267037              -0.260063
#
# ...
